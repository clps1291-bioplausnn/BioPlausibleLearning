# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %matplotlib notebook

import os

from bio_learn import *
from fa_linear import *
# Out:
#   Cell In[26], line 9
#     os.environ['NVIDIA_VISIBLE_DEVICES']= 00000000:01:00.0
#                                                   ^
# SyntaxError: invalid syntax

# %%
(train_X, train_y), (test_X, test_y) = get_data('train'), get_data('test')
print('train_data, test_data:', train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# train_data, test_data: torch.Size([60000, 784]) torch.Size([60000]) torch.Size([10000, 784]) torch.Size([10000])

# %%
import torch

cuda_available = torch.cuda.is_available()
if cuda_available:
    print("CUDA is available")
else:
    print("CUDA is not available")
# Out:
# CUDA is available

# %%
np.random.seed(999)
force = False
file = './data/weights_0.pkl'
if not force and os.path.isfile(file):
    weights = torch.load(file,map_location='cuda:0')
else:
    weights = get_unsupervised_weights(train_X, n_hidden=2000, n_epochs=200, batch_size=3584)          
    if not force: torch.save(weights, file)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> file = './data/weights_0.pkl'
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> if not force and os.path.isfile(file):
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     weights = torch.load(file,map_location='cuda:0')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> else:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     weights = get_unsupervised_weights(train_X, n_hidden=2000, n_epochs=200, batch_size=3584)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:1014, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1012             except RuntimeError as e:
#    1013                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1014         return _load(opened_zipfile,
#    1015                      map_location,
#    1016                      pickle_module,
#    1017                      overall_storage=overall_storage,
#    1018                      **pickle_load_args)
#    1019 if mmap:
#    1020     raise RuntimeError("mmap can only be used with files saved with ",
#    1021                        "`torch.save(_use_new_zipfile_serialization=True), "
#    1022                        "please torch.save your checkpoint with this option in order to use mmap.")
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:1422, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1420 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1421 unpickler.persistent_load = persistent_load
# -> 1422 result = unpickler.load()
#    1424 torch._utils._validate_loaded_sparse_tensors()
#    1425 torch._C._log_api_usage_metadata(
#    1426     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1427 )
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:1392, in _load.<locals>.persistent_load(saved_id)
#    1390 else:
#    1391     nbytes = numel * torch._utils._element_size(dtype)
# -> 1392     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1394 return typed_storage
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:1366, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1361         storage.byteswap(dtype)
#    1363 # TODO: Once we decide to break serialization FC, we can
#    1364 # stop wrapping with TypedStorage
#    1365 typed_storage = torch.storage.TypedStorage(
# -> 1366     wrap_storage=restore_location(storage, location),
#    1367     dtype=dtype,
#    1368     _internal=True)
#    1370 if typed_storage._data_ptr() != 0:
#    1371     loaded_storages[key] = typed_storage
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:1296, in _get_restore_location.<locals>.restore_location(storage, location)
#    1295 def restore_location(storage, location):
# -> 1296     return default_restore_location(storage, map_location)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:381, in default_restore_location(storage, location)
#     379 def default_restore_location(storage, location):
#     380     for _, _, fn in _package_registry:
# --> 381         result = fn(storage, location)
#     382         if result is not None:
#     383             return result
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:274, in _cuda_deserialize(obj, location)
#     272 def _cuda_deserialize(obj, location):
#     273     if location.startswith('cuda'):
# --> 274         device = validate_cuda_device(location)
#     275         if getattr(obj, "_torch_load_uninitialized", False):
#     276             with torch.cuda.device(device):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/serialization.py:265, in validate_cuda_device(location)
#     263 device_count = torch.cuda.device_count()
#     264 if device >= device_count:
# --> 265     raise RuntimeError('Attempting to deserialize object on CUDA device '
#     266                        f'{device} but torch.cuda.device_count() is {device_count}. Please use '
#     267                        'torch.load with map_location to map your storages '
#     268                        'to an existing device.')
#     269 return device
#
# RuntimeError: Attempting to deserialize object on CUDA device 0 but torch.cuda.device_count() is 0. Please use torch.load with map_location to map your storages to an existing device.

# %%
print(torch.cuda.device_count())
# Out:
# 0

# %%
draw_weights(weights.cpu().numpy(), n_cols=5, n_rows=4)

# %%
print('\nSimpleConvNet Model')
SimpleConvNet_model =  SimpleConvNet().to("cuda")
run_test(train_X, train_y, test_X, test_y, SimpleConvNet_model, 10) # 0.97
# Out:
# SimpleConvNet Model
# Final Validation Results - Epoch: 10  Avg accuracy: 0.99 Avg loss: 0.04 Took: 20s

# %%
print('\nBioClassifier Model')
BioClassifier_model =  BioClassifier(BioCell(weights, .1, 10)).to("cuda")
run_test(train_X, train_y, test_X, test_y, BioClassifier_model, 100) # 0.10
# Out:
# BioClassifier Model
# Final Validation Results - Epoch: 100  Avg accuracy: 0.90 Avg loss: 1.01 Took: 123s

# %%
print('\nSimpleBioClassifier Model')
# run_test(train_X, train_y, test_X, test_y, SimpleBioClassifier(weights, 10), 100, 1e-2) # 0.90 
run_test(train_X, train_y, test_X, test_y, SimpleBioClassifier(weights, 10).to("cuda"), 100) # 0.90
# Out:
# SimpleBioClassifier Model
# Final Validation Results - Epoch: 100  Avg accuracy: 0.84 Avg loss: 0.90 Took: 119s

# %%
print('\nBioConvClassifier Model')
run_test(train_X, train_y, test_X, test_y, BioConvClassifier(weights, 10), 20, 1e-2) # 0.11
# Out:
# BioConvClassifier Model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> print('\nBioConvClassifier Model')
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> run_test(train_X, train_y, test_X, test_y, BioConvClassifier(weights, 10), 20, 1e-2) # 0.11
#
# File ~/clps_project/unsupervised_bio_classifier/src/bio_learn.py:77, in run_test(train_X, train_y, test_X, test_y, model, epochs, batch_size, lr, verbose, loss)
#      75 start = time()
#      76 train_ds = TensorDataset(train_X, train_y)
# ---> 77 train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
#      78 test_ds = TensorDataset(test_X, test_y)
#      79 test_dl = DataLoader(test_ds, batch_size=batch_size, shuffle=False)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/utils/data/dataloader.py:355, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     351             sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#     353 if batch_size is not None and batch_sampler is None:
#     354     # auto_collation without custom batch_sampler
# --> 355     batch_sampler = BatchSampler(sampler, batch_size, drop_last)
#     357 self.batch_size = batch_size
#     358 self.drop_last = drop_last
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/utils/data/sampler.py:262, in BatchSampler.__init__(self, sampler, batch_size, drop_last)
#     256 def __init__(self, sampler: Union[Sampler[int], Iterable[int]], batch_size: int, drop_last: bool) -> None:
#     257     # Since collections.abc.Iterable does not check for `__getitem__`, which
#     258     # is one way for an object to be an iterable, we don't do an `isinstance`
#     259     # check here.
#     260     if not isinstance(batch_size, int) or isinstance(batch_size, bool) or \
#     261             batch_size <= 0:
# --> 262         raise ValueError(f"batch_size should be a positive integer value, but got batch_size={batch_size}")
#     263     if not isinstance(drop_last, bool):
#     264         raise ValueError(f"drop_last should be a boolean value, but got drop_last={drop_last}")
#
# ValueError: batch_size should be a positive integer value, but got batch_size=0.01

# %%
print('\nBioConvClassifier2 Model')
#run_test(train_X, train_y, test_X, test_y, BioConvClassifier2_model, 10, 1e-2) # 0.11 
run_test(train_X, train_y, test_X, test_y, BioConvClassifier2(weights).to("cuda"), 10) # 0.11
# Out:
# Current run is terminating due to exception: Given input size: (2000x1x1). Calculated output size: (2000x0x0). Output size is too small
# Engine run is terminating due to exception: Given input size: (2000x1x1). Calculated output size: (2000x0x0). Output size is too small
# BioConvClassifier2 Model
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> print('\nBioConvClassifier2 Model')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> #run_test(train_X, train_y, test_X, test_y, BioConvClassifier2_model, 10, 1e-2) # 0.11
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/yingwei/clps_project/unsupervised_bio_classifier/src/0010_bio_learn_initial_classifier_converging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> run_test(train_X, train_y, test_X, test_y, BioConvClassifier2(weights).to("cuda"), 10) # 0.11
#
# File ~/clps_project/unsupervised_bio_classifier/src/bio_learn.py:112, in run_test(train_X, train_y, test_X, test_y, model, epochs, batch_size, lr, verbose, loss)
#     109     avg_nll = metrics['nll']
#     110     print("Final Validation Results - Epoch: {}  Avg accuracy: {:.2f} Avg loss: {:.2f} Took: {:.0f}s".format(engine.state.epoch, avg_accuracy, avg_nll, time() - start))
# --> 112 trainer.run(train_dl, max_epochs=epochs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:898, in Engine.run(self, data, max_epochs, epoch_length, seed)
#     895     self.state.dataloader = data
#     897 if self.interrupt_resume_enabled:
# --> 898     return self._internal_run()
#     899 else:
#     900     return self._internal_run_legacy()
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:941, in Engine._internal_run(self)
#     939     self._internal_run_generator = self._internal_run_as_gen()
#     940 try:
# --> 941     return next(self._internal_run_generator)
#     942 except StopIteration as out:
#     943     self._internal_run_generator = None
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:999, in Engine._internal_run_as_gen(self)
#     997     self._dataloader_iter = None
#     998     self.logger.error(f"Engine run is terminating due to exception: {e}")
# --> 999     self._handle_exception(e)
#    1001 self._dataloader_iter = None
#    1002 return self.state
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:644, in Engine._handle_exception(self, e)
#     642     self._fire_event(Events.EXCEPTION_RAISED, e)
#     643 else:
# --> 644     raise e
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:965, in Engine._internal_run_as_gen(self)
#     962 if self._dataloader_iter is None:
#     963     self._setup_engine()
# --> 965 epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#     967 # time is available for handlers but must be updated after fire
#     968 self.state.times[Events.EPOCH_COMPLETED.name] = epoch_time_taken
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:1093, in Engine._run_once_on_dataset_as_gen(self)
#    1091 except Exception as e:
#    1092     self.logger.error(f"Current run is terminating due to exception: {e}")
# -> 1093     self._handle_exception(e)
#    1095 return time.time() - start_time
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:644, in Engine._handle_exception(self, e)
#     642     self._fire_event(Events.EXCEPTION_RAISED, e)
#     643 else:
# --> 644     raise e
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/engine.py:1074, in Engine._run_once_on_dataset_as_gen(self)
#    1071 self._fire_event(Events.ITERATION_STARTED)
#    1072 yield from self._maybe_terminate_or_interrupt()
# -> 1074 self.state.output = self._process_function(self, self.state.batch)
#    1075 self._fire_event(Events.ITERATION_COMPLETED)
#    1076 yield from self._maybe_terminate_or_interrupt()
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/__init__.py:112, in supervised_training_step.<locals>.update(engine, batch)
#     110 model.train()
#     111 x, y = prepare_batch(batch, device=device, non_blocking=non_blocking)
# --> 112 output = model_fn(model, x)
#     113 y_pred = model_transform(output)
#     114 loss = loss_fn(y_pred, y)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/ignite/engine/__init__.py:434, in <lambda>(model, x)
#     417     else:
#     418         return amp_mode, None
#     421 def create_supervised_trainer(
#     422     model: torch.nn.Module,
#     423     optimizer: torch.optim.Optimizer,
#     424     loss_fn: Union[Callable[[Any, Any], torch.Tensor], torch.nn.Module],
#     425     device: Optional[Union[str, torch.device]] = None,
#     426     non_blocking: bool = False,
#     427     prepare_batch: Callable = _prepare_batch,
#     428     model_transform: Callable[[Any], Any] = lambda output: output,
#     429     output_transform: Callable[[Any, Any, Any, torch.Tensor], Any] = lambda x, y, y_pred, loss: loss.item(),
#     430     deterministic: bool = False,
#     431     amp_mode: Optional[str] = None,
#     432     scaler: Union[bool, "torch.cuda.amp.GradScaler"] = False,
#     433     gradient_accumulation_steps: int = 1,
# --> 434     model_fn: Callable[[torch.nn.Module, Any], Any] = lambda model, x: model(x),
#     435 ) -> Engine:
#     436     """Factory function for creating a trainer for supervised models.
#     437
#     438     Args:
#    (...)
#     548         Added `model_fn` to customize model's application on the sample
#     549     """
#     551     device_type = device.type if isinstance(device, torch.device) else device
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/clps_project/unsupervised_bio_classifier/src/bio_learn.py:248, in forward(self, x)
#     245     self.fc1 = LinearFAModule(256, 1024)
#     246     self.fc2 = LinearFAModule(1024, 10)
# --> 248 def forward(self, x): # 64, 784
#     249     x = self.conv1(x) # 64, 2000, 1, 1
#     250     x = F.relu(F.max_pool2d(x, 2)) # 64, 2000, 1, 1
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/_jit_internal.py:488, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     486     return if_true(*args, **kwargs)
#     487 else:
# --> 488     return if_false(*args, **kwargs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/nn/functional.py:791, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     789 if stride is None:
#     790     stride = torch.jit.annotate(List[int], [])
# --> 791 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# RuntimeError: Given input size: (2000x1x1). Calculated output size: (2000x0x0). Output size is too small

# %%
print('\nBioClassifier w/ BioCell2 Model')
run_test(train_X, train_y, test_X, test_y, BioClassifier(BioCell2(weights)), 10) # 0.10
# Out:
# BioClassifier w/ BioCell2 Model

# %%
print('\nBioClassifier w/ BioCell3 Model')
run_test(train_X, train_y, test_X, test_y, BioClassifier(BioCell3(weights)), 100) # 0.10

# %%
'''
200 epochs: 0.27 (200 epochs) 
switched WxH: 0.52
lr=1e-3: 0.94 -- SimpleConvNet got .97, modern SOTA is + .99
300 epochs: 0.97 
without switched WxH (takes 488s): 0.96
batch_size=1024 (takes 169s): 0.97 
batch_size=2048 (takes 168s): 0.97 
batch_size=3584 (takes 166s): 0.97 
nn.DataParallel (takes 167s): 0.97 -- undo
'''
print('\nBioClassifier w/ BioCell3 Model w/ BioLoss')
model = BioClassifier(BioCell3(weights))
run_test(train_X, train_y, test_X, test_y, model, 300, batch_size=3584, lr=1e-4, loss=BioLoss(m=6))
# Out:
# BioClassifier w/ BioCell3 Model w/ BioLoss
# Final Validation Results - Epoch: 300  Avg accuracy: 0.97 Avg loss: 1174077.06 Took: 168s

# %%
file = '../data/0010_model.pkl'
torch.save(model, file)
